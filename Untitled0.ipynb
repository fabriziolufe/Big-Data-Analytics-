# %% [markdown]
# <a href="https://colab.research.google.com/github/fabriziolufe/Big-Data-Analytics-/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # I am importing pandas library and for futre us pd to refer to it
import numpy as np
 
data = pd.read_csv("5000-Sales-Records.csv")
data
# Out:
#                                  Region  ... Total Profit
# 0     Central America and the Caribbean  ...     52914.72
# 1     Central America and the Caribbean  ...    119488.38
# 2                                Europe  ...     74823.48
# 3                                  Asia  ...    798727.44
# 4                                  Asia  ...    415865.88
# ...                                 ...  ...          ...
# 4995              Australia and Oceania  ...    879197.65
# 4996       Middle East and North Africa  ...     79094.88
# 4997                               Asia  ...    498855.44
# 4998                             Europe  ...    691070.40
# 4999                 Sub-Saharan Africa  ...    154668.50
#
# [5000 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          5000 non-null   object
#  1   Country         5000 non-null   object
#  2   Item Type       5000 non-null   object
#  3   Sales Channel   5000 non-null   object
#  4   Order Priority  5000 non-null   object
#  5   Order Date      5000 non-null   object
#  6   Order ID        5000 non-null   int64
#  7   Ship Date       5000 non-null   object
#  8   Units Sold      5000 non-null   int64
#  9   Unit Price      5000 non-null   float64
#  10  Unit Cost       5000 non-null   float64
#  11  Total Revenue   5000 non-null   float64
#  12  Total Cost      5000 non-null   float64
#  13  Total Profit    5000 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 547.0+ KB

# %%
#  Filter data and only add Region, Country, Item Type, Sales Channel
#  Filter only 10 lines
#  Filter by sales channels = online
 
data_filter_task = data [['Region', 'Country', 'Item Type', 'Sales Channel']]
data_filter_task = data_filter_task[data_filter_task['Sales Channel']=='Online']
data_filter_task[0:10]
# Out:
#                                Region  ... Sales Channel
# 0   Central America and the Caribbean  ...        Online
# 7                              Europe  ...        Online
# 9                  Sub-Saharan Africa  ...        Online
# 11       Middle East and North Africa  ...        Online
# 14  Central America and the Caribbean  ...        Online
# 17                             Europe  ...        Online
# 18                      North America  ...        Online
# 22                             Europe  ...        Online
# 25  Central America and the Caribbean  ...        Online
# 27  Central America and the Caribbean  ...        Online
#
# [10 rows x 4 columns]

# %%
data.head()
# Out:
#                               Region  ... Total Profit
# 0  Central America and the Caribbean  ...     52914.72
# 1  Central America and the Caribbean  ...    119488.38
# 2                             Europe  ...     74823.48
# 3                               Asia  ...    798727.44
# 4                               Asia  ...    415865.88
#
# [5 rows x 14 columns]

# %%
# Descriptive Analysis : Centeral Tendencies
data.describe()
# Out:
#            Order ID   Units Sold  ...    Total Cost  Total Profit
# count  5.000000e+03  5000.000000  ...  5.000000e+03  5.000000e+03
# mean   5.486447e+08  5030.698200  ...  9.330932e+05  3.926446e+05
# std    2.594671e+08  2914.515427  ...  1.150873e+06  3.829351e+05
# min    1.000909e+08     2.000000  ...  4.844000e+01  1.687000e+01
# 25%    3.201042e+08  2453.000000  ...  1.547480e+05  8.533925e+04
# 50%    5.523150e+08  5123.000000  ...  4.681807e+05  2.790952e+05
# 75%    7.687709e+08  7576.250000  ...  1.189578e+06  5.651064e+05
# max    9.998797e+08  9999.000000  ...  5.248025e+06  1.726007e+06
#
# [8 rows x 7 columns]

# %%
data_total_cost = data[['Total Cost']]
data_total_cost[0:5]
# Out:
#    Total Cost
# 0    87999.84
# 1   211152.48
# 2   151892.62
# 3  1055863.76
# 4   734892.48

# %%
df_total_cost = pd.DataFrame(data_total_cost)
df_total_cost.to_csv("out.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Exploratory Data Analaysis
sns.distplot(data_total_cost ,bins = 50)
plt.show()

# %%
x = np.random.normal(size=100)
sns.distplot(x);

# %%
sns.distplot(x, kde=False, rug=True);

# %%
# Task: Get 50 lines from "Unit Cost" and "Total Profit" and save it to the file unit_cost.csv
data_unitcost = data[['Unit Cost', 'Total Profit' ]]
data_unitcost[0:50]
# Out:
#     Unit Cost  Total Profit
# 0      159.42      52914.72
# 1       97.44     119488.38
# 2       31.79      74823.48
# 3      117.11     798727.44
# 4       97.44     415865.88
# 5       56.67       1202.88
# 6       35.84     606467.52
# 7       35.84      68078.88
# 8       35.84     649283.04
# 9      159.42     941057.62
# 10     524.96     467630.00
# 11     263.33    1283508.34
# 12     117.11     864815.58
# 13     263.33    1179881.82
# 14     159.42     616188.08
# 15     364.69     211239.60
# 16     117.11     497521.44
# 17     524.96     791082.50
# 18      31.79      27279.72
# 19     159.42     495787.92
# 20      31.79      26903.88
# 21     159.42     342411.92
# 22       6.92      11948.78
# 23      31.79     111687.12
# 24      97.44     186262.92
# 25     117.11     355688.85
# 26       6.92       3349.90
# 27     524.96     616731.25
# 28     159.42     566532.60
# 29      97.44     160291.98
# 30     263.33    1104074.50
# 31      35.84     274959.36
# ...

# %%
df_total_cost = pd.DataFrame(data_unitcost)
df_total_cost.to_csv("unit_cost.csv")
